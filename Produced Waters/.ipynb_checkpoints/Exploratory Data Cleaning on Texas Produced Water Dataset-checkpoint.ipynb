# %% [markdown]
# The following code was implemented to clean the datasets obtained from the United States Geological Survey (USGS) National Produced Waters Database v2.3: https://energy.usgs.gov/EnvironmentalAspects/EnvironmentalAspectsofEnergyProductionandUse/ProducedWaters.aspx#3822349-data
#
# The major steps taken are to analyze and visualize the produced water data from the Texas well set.

# %% [markdown]
# First the major libraries are imported, and the file read into a Pandas dataframe, df.

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
file = 'Texas Wells.xlsx'
df = pd.read_excel(file)

# %% [markdown]
# To fill in some of the missing data, I created two similar functions, as follows. In essence, the functions capture a list of rows with the missing attribute, and then search for their API numbers. A smaller dataframe with similar API numbers is then created. The first function fills in the missing latitudes and longitudes by copying these data from the rows where it is given. The second function fills in the missing upper depth and lower depth values by taking the average of the rows where it is given. The return values are the total number of data points that have been changed.

# %% [markdown]
# Next, to analyze the data contained within this huge dataset, one can use the .info() and .head() method.

# %%
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19388 entries, 0 to 19387
# Columns: 190 entries, IDUSGS to cull_chargeb
# dtypes: float64(104), int64(2), object(84)
# memory usage: 28.1+ MB
#    IDUSGS     IDORIG          IDDB  \
# 0     177  14-TX-01B  PERMIANENGLE
# 1     178  14-TX-02B  PERMIANENGLE
# 2     179  14-TX-03B  PERMIANENGLE
# 3     180  14-TX-04B  PERMIANENGLE
# 4     181  14-TX-05B  PERMIANENGLE
#
#                                               SOURCE  \
# 0  Engle, M.A., Reyes, F.R., Varonka, M.S., Orem,...
# 1  Engle, M.A., Reyes, F.R., Varonka, M.S., Orem,...
# 2  Engle, M.A., Reyes, F.R., Varonka, M.S., Orem,...
# 3  Engle, M.A., Reyes, F.R., Varonka, M.S., Orem,...
# 4  Engle, M.A., Reyes, F.R., Varonka, M.S., Orem,...
#
#                                            REFERENCE  LATITUDE  LONGITUDE  \
# 0  Engle, M.A., Reyes, F.R., Varonka, M.S., Orem,...     31.90    -101.44
# 1  Engle, M.A., Reyes, F.R., Varonka, M.S., Orem,...     31.91    -101.44
# 2  Engle, M.A., Reyes, F.R., Varonka, M.S., Orem,...     31.86    -101.47
# 3  Engle, M.A., Reyes, F.R., Varonka, M.S., Orem,...     31.99    -101.49
# 4  Engle, M.A., Reyes, F.R., Varonka, M.S., Orem,...     31.98    -101.49
#
#                                 LATLONGAPX  API  \
# 0  Latitude and Longitude are approximate.  NaN
# 1  Latitude and Longitude are approximate.  NaN
# 2  Latitude and Longitude are approximate.  NaN
# 3  Latitude and Longitude are approximate.  NaN
# 4  Latitude and Longitude are approximate.  NaN
#
#                           USGSREGION  ... Sr87Sr86  I129 Rn222  Ra226 Ra228  \
# 0  West Texas and Eastern New Mexico  ...  0.71744   NaN   NaN    NaN   NaN
# 1  West Texas and Eastern New Mexico  ...  0.70920   NaN   NaN    NaN   NaN
# 2  West Texas and Eastern New Mexico  ...  0.70891   NaN   NaN    NaN   NaN
# 3  West Texas and Eastern New Mexico  ...  0.70912   NaN   NaN    NaN   NaN
# 4  West Texas and Eastern New Mexico  ...  0.71780   NaN   NaN    NaN   NaN
#
#    cull_PH cull_MgCa cull_KCl cull_K5Na  cull_chargeb
# 0      NaN       NaN      NaN       NaN           NaN
# 1      NaN       NaN      NaN       NaN           NaN
# 2      NaN       NaN      NaN       NaN           NaN
# 3      NaN       NaN      NaN       NaN             X
# 4      NaN       NaN      NaN       NaN           NaN
#
# [5 rows x 190 columns]

# %% [markdown]
# Since there are 190 columns and 19388 entries, some data cleaning needs to be implemented. There are multiple columns in the dataset that are empty, and so the first step is to remove them, and add them to a new dataframe, df_drop.

# %%
# deleting columns that are null values
df_drop = df.dropna(axis= 1, how='all')

print(df.info())
print(df_drop.info())

# number of attributes dropped to 129 from 190
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19388 entries, 0 to 19387
# Columns: 190 entries, IDUSGS to cull_chargeb
# dtypes: float64(104), int64(2), object(84)
# memory usage: 28.1+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19388 entries, 0 to 19387
# Columns: 129 entries, IDUSGS to cull_chargeb
# dtypes: float64(43), int64(2), object(84)
# memory usage: 19.1+ MB
# None

# %% [markdown]
# I then cleaned up the data by focusing only on the main parameters of interest, i.e. 'LATITUDE', 'LONGITUDE', 'API', 'USREGION', 'BASIN', 'COUNTY', 'WELLNAME', 'WELLTYPE', 'DATECOMP', 'DATESAMPLE', 'FORMATION', 'PERIOD', 'DEPTHUPPER', 'DEPTHLOWER', 'DEPTHWELL', 'SPGRAV', 'PH', 'TDSUSGS', 'HCO3', 'Ca', 'Cl', 'KNa', 'Mg', 'Na', 'SO4', 'H2S', 'cull_chargeb'.

# %%
# selecting known wells with API numbers
df_drop = df_drop[['LATITUDE','LONGITUDE','API','BASIN','COUNTY','WELLNAME','WELLTYPE','DATECOMP','DATESAMPLE','FORMATION','PERIOD','DEPTHUPPER','DEPTHLOWER','DEPTHWELL','SPGRAV','PH','TDSUSGS','HCO3','Ca','Cl','KNa','Mg','Na','SO4','H2S','cull_chargeb']]      
df_drop.head()
# Out:
#    LATITUDE  LONGITUDE  API    BASIN     COUNTY WELLNAME  \
# 0     31.90    -101.44  NaN  Permian  Glasscock      NaN
# 1     31.91    -101.44  NaN  Permian  Glasscock      NaN
# 2     31.86    -101.47  NaN  Permian  Glasscock      NaN
# 3     31.99    -101.49  NaN  Permian  Glasscock      NaN
# 4     31.98    -101.49  NaN  Permian  Glasscock      NaN
#
#                    WELLTYPE DATECOMP  DATESAMPLE  \
# 0  Conventional Hydrocarbon      NaN  2014-01-23
# 1                 Tight Oil      NaN  2014-01-23
# 2  Conventional Hydrocarbon      NaN  2014-01-23
# 3                 Tight Oil      NaN  2014-01-23
# 4  Conventional Hydrocarbon      NaN  2014-01-23
#
#                       FORMATION  ...   TDSUSGS  HCO3    Ca     Cl  KNa    Mg  \
# 0                     Fusselman  ...   69000.0   NaN  2190  39800  NaN   403
# 1                   Cline Shale  ...   79900.0   NaN  2450  46300  NaN   329
# 2  Wolfwood (Wolfcamp/Woodford)  ...  127000.0   NaN  8010  75100  NaN  1130
# 3                   Cline Shale  ...   37700.0   NaN   572  13400  NaN  78.2
# 4                     Fusselman  ...   72400.0   NaN  2470  40900  NaN   474
#
#       Na   SO4  H2S cull_chargeb
# 0  22200  1580  NaN          NaN
# 1  25200   351  NaN          NaN
# 2  36800   304  NaN          NaN
# 3  12900  <300  NaN            X
# 4  22700  1530  NaN          NaN
#
# [5 rows x 26 columns]

# %% [markdown]
# Thus the final number of parameters fell down to 26. I also converted dates to datetime format.

# %%
# converting dates to datetime
df_drop.DATECOMP = pd.to_datetime(df_drop.DATECOMP)
df_drop.DATESAMPLE = pd.to_datetime(df_drop.DATESAMPLE)

print(df_drop.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19388 entries, 0 to 19387
# Data columns (total 26 columns):
# LATITUDE        16631 non-null float64
# LONGITUDE       16635 non-null float64
# API             8208 non-null float64
# BASIN           19388 non-null object
# COUNTY          19317 non-null object
# WELLNAME        19087 non-null object
# WELLTYPE        19388 non-null object
# DATECOMP        1648 non-null datetime64[ns]
# DATESAMPLE      16734 non-null datetime64[ns]
# FORMATION       19388 non-null object
# PERIOD          19388 non-null object
# DEPTHUPPER      13614 non-null float64
# DEPTHLOWER      11050 non-null float64
# DEPTHWELL       9276 non-null float64
# SPGRAV          16943 non-null object
# PH              16406 non-null object
# TDSUSGS         19373 non-null float64
# HCO3            18664 non-null object
# Ca              19366 non-null object
# Cl              19375 non-null object
# KNa             2345 non-null object
# Mg              19358 non-null object
# Na              17037 non-null object
# SO4             18872 non-null object
# H2S             6197 non-null object
# cull_chargeb    2632 non-null object
# dtypes: datetime64[ns](2), float64(7), object(17)
# memory usage: 3.8+ MB
# None

# %%
#Analyzing the lat and long data
print('Null values for the Latitude: ' + str(df_drop.LATITUDE.isnull().sum()))
print('Null values for the Longitude: ' + str(df_drop.LONGITUDE.isnull().sum()))
# Out:
# Null values for the Latitude: 2757
# Null values for the Longitude: 2753

# %%
#Dropped the empty lat/lon values
df_drop = df_drop[df_drop.LATITUDE.notnull()]
df_drop = df_drop[df_drop.LONGITUDE.notnull()]
df_drop.head()
# Out:
#    LATITUDE  LONGITUDE  API    BASIN     COUNTY WELLNAME  \
# 0     31.90    -101.44  NaN  Permian  Glasscock      NaN
# 1     31.91    -101.44  NaN  Permian  Glasscock      NaN
# 2     31.86    -101.47  NaN  Permian  Glasscock      NaN
# 3     31.99    -101.49  NaN  Permian  Glasscock      NaN
# 4     31.98    -101.49  NaN  Permian  Glasscock      NaN
#
#                    WELLTYPE DATECOMP DATESAMPLE                     FORMATION  \
# 0  Conventional Hydrocarbon      NaT 2014-01-23                     Fusselman
# 1                 Tight Oil      NaT 2014-01-23                   Cline Shale
# 2  Conventional Hydrocarbon      NaT 2014-01-23  Wolfwood (Wolfcamp/Woodford)
# 3                 Tight Oil      NaT 2014-01-23                   Cline Shale
# 4  Conventional Hydrocarbon      NaT 2014-01-23                     Fusselman
#
#    ...   TDSUSGS  HCO3    Ca     Cl  KNa    Mg     Na   SO4  H2S cull_chargeb
# 0  ...   69000.0   NaN  2190  39800  NaN   403  22200  1580  NaN          NaN
# 1  ...   79900.0   NaN  2450  46300  NaN   329  25200   351  NaN          NaN
# 2  ...  127000.0   NaN  8010  75100  NaN  1130  36800   304  NaN          NaN
# 3  ...   37700.0   NaN   572  13400  NaN  78.2  12900  <300  NaN            X
# 4  ...   72400.0   NaN  2470  40900  NaN   474  22700  1530  NaN          NaN
#
# [5 rows x 26 columns]

# %%
column = 'DEPTHUPPER'
col_missing = df_drop[df_drop[column].isnull()].reset_index() 
slices_last = pd.DataFrame()
filled_depths = []            #list of dataframes with each entry = one well 

for i in range(len(col_missing)):         #len(col_missing
    
    slices = df_drop[df_drop.LATITUDE.isin([col_missing.LATITUDE[i]]) & df_drop.LONGITUDE.isin([col_missing.LONGITUDE[i]])]
    slices = slices.sort_values(by=[column]).reset_index()
    
    if i == 0:
        #initializing value of slices_last 
        slices_last = slices
        
    if slices.LATITUDE[0] != slices_last.LATITUDE[0]:             # and len(slices) != 1
        #to make sure that repeats are not found, and that the unique (single) wells are not returned
        
        print('index: ' + str(i), slices[['LATITUDE','LONGITUDE','WELLNAME','DEPTHUPPER','DEPTHLOWER']])
        
        if pd.notnull(slices[column]).any(): 
        
            mean = slices[column].mean() 
            
            #if the block of wells with this particular lat/long have any of depths
            #filled in, then fill the NaNs with the means of those depths
            
            if np.std(slices[column]) <= 400:
                #Check for not naming different levels of the well section accidentally, and be restricted to 
                #one formation only
                
                slices.fillna({column:mean}, inplace=True)
                filled_depths.append(slices)
                #null_slice = slices[slices.DEPTHUPPER.isnull()]
                #test = df_drop.column.replace(null_slice.column,mean, inplace=True)
                #inds = slices['index']
                #df_drop_c.loc[inds,column] = df_drop_c.loc[inds,column].fillna(mean, inplace=True)
                print('index: ' + str(i), slices[['LATITUDE','LONGITUDE','WELLNAME','DEPTHUPPER','DEPTHLOWER']])
                
        else:
            filled_depths.append(slices)
                
    slices_last = slices
# Out:
# index: 1    LATITUDE  LONGITUDE WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0     32.07    -101.63      NaN         NaN         NaN
# index: 2    LATITUDE  LONGITUDE WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0     32.08    -101.64      NaN         NaN         NaN
# index: 3    LATITUDE  LONGITUDE WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0     31.98    -102.39      NaN         NaN         NaN
# 1     31.98    -102.39      NaN         NaN         NaN
# index: 5    LATITUDE  LONGITUDE WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0     31.99    -102.38      NaN         NaN         NaN
# index: 7    LATITUDE  LONGITUDE WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0     31.21    -101.04      NaN         NaN         NaN
# index: 8    LATITUDE  LONGITUDE WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0     31.26    -101.06      NaN      6470.0         NaN
# 1     31.26    -101.06      NaN         NaN         NaN
# 2     31.26    -101.06      NaN         NaN         NaN
# index: 8    LATITUDE  LONGITUDE WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0     31.26    -101.06      NaN      6470.0         NaN
# 1     31.26    -101.06      NaN      6470.0         NaN
# 2     31.26    -101.06      NaN      6470.0         NaN
# index: 10    LATITUDE  LONGITUDE            WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   30.4701  -93.82477  HUMBLE HANKAMER #1         NaN     10840.0
# index: 11    LATITUDE  LONGITUDE      WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.2384  -101.3886  J R Scott #3         NaN         NaN
# index: 12    LATITUDE  LONGITUDE      WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.2456  -101.3966  J R Scott #7         NaN         NaN
# index: 13    LATITUDE  LONGITUDE          WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.2348   -101.759  University 23 #1         NaN         NaN
# index: 14    LATITUDE  LONGITUDE           WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   32.4823  -101.4869  Edward Simpson #1         NaN         NaN
# index: 15    LATITUDE  LONGITUDE          WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   32.4646  -101.1865  C. L. Jones a #1         NaN         NaN
# index: 16    LATITUDE  LONGITUDE                 WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   32.0631  -100.6965         W. I. Tubbs B-#1      6359.0         NaN
# 1   32.0631  -100.6965                  Jru 1-q      6359.0      6486.0
# 2   32.0631  -100.6965  W. I. Tubb B-1 (jru-1q)         NaN         NaN
# 3   32.0631  -100.6965                  Jru 1-q         NaN         NaN
# index: 16    LATITUDE  LONGITUDE                 WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   32.0631  -100.6965         W. I. Tubbs B-#1      6359.0         NaN
# 1   32.0631  -100.6965                  Jru 1-q      6359.0      6486.0
# 2   32.0631  -100.6965  W. I. Tubb B-1 (jru-1q)      6359.0         NaN
# 3   32.0631  -100.6965                  Jru 1-q      6359.0         NaN
# index: 18    LATITUDE  LONGITUDE         WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.6289  -100.8424  Geo. Weddell #5         NaN         NaN
# index: 19    LATITUDE  LONGITUDE                    WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0    32.731  -101.0145  Sacroc 3, Tr. 225, Well #3         NaN         NaN
# 1    32.731  -101.0145          Sacroc 3 No. 225-3         NaN         NaN
# index: 21    LATITUDE  LONGITUDE                       WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   32.7374  -101.0144  Sacroc Unit, Tr. 225, Well #1         NaN         NaN
# 1   32.7374  -101.0144                 Sacroc 3 225-1         NaN         NaN
# 2   32.7374  -101.0144                Sacroc 3 #225-1         NaN         NaN
# 3   32.7374  -101.0144     Sacroc 3 Tract 225 Well #1         NaN         NaN
# index: 25    LATITUDE  LONGITUDE            WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   32.7212  -101.0493      Sacroc 3 255-1         NaN         NaN
# 1   32.7212  -101.0493  Sacroc 3 No. 255-1         NaN         NaN
# 2   32.7212  -101.0493   Sacroc Unit 255-1         NaN         NaN
# index: 28    LATITUDE  LONGITUDE             WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   32.6776  -101.0591  Sacroc Unit 327 A-1         NaN         NaN
# index: 29    LATITUDE  LONGITUDE          WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0    32.783  -101.0202  Sacroc 3 107a #1         NaN         NaN
# index: 30    LATITUDE  LONGITUDE         WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   32.7795  -101.0298  Mc Donnell I #1      6926.0         NaN
# 1   32.7795  -101.0298  Sacroc 3 105 #1         NaN         NaN
# index: 30    LATITUDE  LONGITUDE         WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   32.7795  -101.0298  Mc Donnell I #1      6926.0         NaN
# 1   32.7795  -101.0298  Sacroc 3 105 #1      6926.0         NaN
# index: 31    LATITUDE  LONGITUDE         WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   32.7981  -101.0156  Sacroc 3 99a #1         NaN         NaN
# index: 32    LATITUDE  LONGITUDE        WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   32.6698  -101.0463  Sacroc 3 344-2         NaN         NaN
# 1   32.6698  -101.0463   H H Eiland #2         NaN         NaN
# index: 33    LATITUDE  LONGITUDE        WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   32.6697  -101.0424  Sacroc 3 344-3         NaN         NaN
# 1   32.6697  -101.0424  Sacroc 3 343-3         NaN         NaN
# index: 35    LATITUDE  LONGITUDE                    WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   32.7312  -101.0263  Sacroc 3, Tr. 230, Well #2         NaN         NaN
# 1   32.7312  -101.0263          Sacroc 3 No. 230-2         NaN         NaN
# index: 37    LATITUDE  LONGITUDE           WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   32.6452  -100.9889  W. B. Penton a #2         NaN         NaN
# index: 38    LATITUDE  LONGITUDE                         WELLNAME  DEPTHUPPER  \
# 0    32.704  -101.0119  Mae Lemmons 9 Sacroc Unit 295-9      6801.0
# 1    32.704  -101.0119                  Sacroc 3 295 #9         NaN
#
#    DEPTHLOWER
# 0      6841.0
# 1         NaN
# index: 38    LATITUDE  LONGITUDE                         WELLNAME  DEPTHUPPER  \
# 0    32.704  -101.0119  Mae Lemmons 9 Sacroc Unit 295-9      6801.0
# 1    32.704  -101.0119                  Sacroc 3 295 #9      6801.0
#
#    DEPTHLOWER
# 0      6841.0
# 1         NaN
# index: 39    LATITUDE  LONGITUDE                      WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0    32.707  -101.0667  Sacroc 3, Tract 305, Well #1         NaN         NaN
# 1    32.707  -101.0667               Sacroc 3 #305-1         NaN         NaN
# index: 40    LATITUDE  LONGITUDE      WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   32.6948  -101.0068  Tract 296 #3         NaN         NaN
# index: 41    LATITUDE  LONGITUDE               WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   32.6993   -101.001  Sacroc 3 Tract 296 #1         NaN         NaN
# index: 42    LATITUDE  LONGITUDE         WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   32.7795  -101.0328  Sacroc 3 103 #1         NaN         NaN
# index: 43    LATITUDE  LONGITUDE      WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   32.7697  -101.0331  Tract 160 #2         NaN         NaN
# index: 44    LATITUDE  LONGITUDE      WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   32.7581  -101.0341  Tract 160 #1         NaN         NaN
# index: 45    LATITUDE  LONGITUDE                             WELLNAME  DEPTHUPPER  \
# 0   32.7527  -101.0424  Sacroc Unit, Segment 3, Tract 162-1      6872.0
# 1   32.7527  -101.0424                Sacroc 3 Tract 162 #1         NaN
#
#    DEPTHLOWER
# 0         NaN
# 1         NaN
# index: 45    LATITUDE  LONGITUDE                             WELLNAME  DEPTHUPPER  \
# 0   32.7527  -101.0424  Sacroc Unit, Segment 3, Tract 162-1      6872.0
# 1   32.7527  -101.0424                Sacroc 3 Tract 162 #1      6872.0
#
#    DEPTHLOWER
# 0         NaN
# 1         NaN
# index: 46    LATITUDE  LONGITUDE        WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   32.7211  -101.0351  Sacroc 3 257-4         NaN         NaN
# 1   32.7211  -101.0351    Sacroc 257-4         NaN         NaN
# 2   32.7211  -101.0351  Sacroc 3 257-4         NaN         NaN
# index: 49    LATITUDE  LONGITUDE         WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   32.7062  -101.0069  Sacroc 3 491 #1         NaN         NaN
# index: 50    LATITUDE  LONGITUDE      WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   32.7288  -101.0405  Sacroc 256-1         NaN         NaN
# index: 51    LATITUDE  LONGITUDE        WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   32.7287  -101.0349  Sacroc 3 256-3         NaN         NaN
# 1   32.7287  -101.0349  Sacroc 3 256-3         NaN         NaN
# index: 53    LATITUDE  LONGITUDE           WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   32.7165  -101.0407  Sacroc Unit 257-2         NaN         NaN
# 1   32.7165  -101.0407     Sacroc 3 257-2         NaN         NaN
# index: 55    LATITUDE  LONGITUDE               WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   32.7463  -101.0344  Sacroc 3 Tract 165 #1         NaN         NaN
# index: 57    LATITUDE  LONGITUDE          WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   32.1274  -100.6707  V. T. Mccabe #11         NaN         NaN
# index: 58    LATITUDE  LONGITUDE WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0    31.018  -100.6709      NaN         NaN         NaN
# index: 59    LATITUDE  LONGITUDE             WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   32.7289  -101.0491  Sacroc 3 Well 254-3         NaN         NaN
# index: 60    LATITUDE  LONGITUDE                      WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   32.7167   -101.094             Sacroc Unit 245-4         NaN         NaN
# 1   32.7167   -101.094  Sacroc #3 Tract 245, Well #4         NaN         NaN
# index: 62    LATITUDE  LONGITUDE                 WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   32.7428  -101.0087  Sacroc 3 Well No. 223-1         NaN         NaN
# index: 63    LATITUDE  LONGITUDE        WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   32.7102   -101.087  Sacroc 3 309-1         NaN         NaN
# index: 64    LATITUDE  LONGITUDE                      WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   32.7133   -101.086  Sacroc 3, Tract 309, Well #2         NaN         NaN
# index: 65    LATITUDE  LONGITUDE                      WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   32.7101  -101.0786             Sacroc Unit 307-2         NaN         NaN
# 1   32.7101  -101.0786             Sacroc Unit 307-2         NaN         NaN
# 2   32.7101  -101.0786  Sacroc 3, Tract 307, Well #2         NaN         NaN
# 3   32.7101  -101.0786               Sacroc 3 #307-2         NaN         NaN
# 4   32.7101  -101.0786                Sacroc 3 307-2         NaN         NaN
# index: 70    LATITUDE  LONGITUDE                      WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   32.7133  -101.0829                Sacroc 3 307-3         NaN         NaN
# 1   32.7133  -101.0829            Sacroc Unit 307 #3         NaN         NaN
# 2   32.7133  -101.0829             Sacroc Unit 307-3         NaN         NaN
# 3   32.7133  -101.0829  Sacroc 3, Tract 307, Well #3         NaN         NaN
# index: 74    LATITUDE  LONGITUDE                WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.9697   -103.085    Keystone Cattle Co 2     10336.0     10396.0
# 1   31.9697   -103.085  Keystone Cattle Co. #2         NaN         NaN
# index: 74    LATITUDE  LONGITUDE                WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.9697   -103.085    Keystone Cattle Co 2     10336.0     10396.0
# 1   31.9697   -103.085  Keystone Cattle Co. #2     10336.0         NaN
# index: 75    LATITUDE  LONGITUDE           WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.8792  -102.8224     Ra Wheeler C 1      8000.0         NaN
# 1   31.8792  -102.8224     Ra Wheeler C 1      8475.0      8625.0
# 2   31.8792  -102.8224   R.a. Wheeler 1-c      8540.0      8590.0
# 3   31.8792  -102.8224     Ra Wheeler C 1      8540.0      8590.0
# 4   31.8792  -102.8224     Ra Wheeler C 1      9165.0      9180.0
# 5   31.8792  -102.8224  R.a. Wheeler #1-c         NaN         NaN
# index: 75    LATITUDE  LONGITUDE           WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.8792  -102.8224     Ra Wheeler C 1      8000.0         NaN
# 1   31.8792  -102.8224     Ra Wheeler C 1      8475.0      8625.0
# 2   31.8792  -102.8224   R.a. Wheeler 1-c      8540.0      8590.0
# 3   31.8792  -102.8224     Ra Wheeler C 1      8540.0      8590.0
# 4   31.8792  -102.8224     Ra Wheeler C 1      9165.0      9180.0
# 5   31.8792  -102.8224  R.a. Wheeler #1-c      8544.0         NaN
# index: 76    LATITUDE  LONGITUDE              WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.8572  -102.8066  R.a. Wheeler e No. 1         NaN         NaN
# 1   31.8572  -102.8066          Ra Wheeler 1         NaN         NaN
# 2   31.8572  -102.8066          Ra Wheeler 1         NaN         NaN
# index: 77    LATITUDE  LONGITUDE            WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   32.5133  -100.5005     E.e. Harkins #1      5984.0      5994.0
# 1   32.5133  -100.5005  E.e. Harkins No. 1         NaN         NaN
# index: 77    LATITUDE  LONGITUDE            WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   32.5133  -100.5005     E.e. Harkins #1      5984.0      5994.0
# 1   32.5133  -100.5005  E.e. Harkins No. 1      5984.0         NaN
# index: 78    LATITUDE  LONGITUDE          WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   32.2957  -101.2328  Dodge Estate #17         NaN         NaN
# index: 79    LATITUDE  LONGITUDE          WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   32.2874   -101.219  Dodge Estate #59         NaN         NaN
# index: 80    LATITUDE  LONGITUDE   WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.4871  -102.7666  Tubb #1-b         NaN         NaN
# index: 81    LATITUDE  LONGITUDE       WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   32.5529  -102.7319  Wl Hawkins #1         NaN         NaN
# 1   32.5529  -102.7319  Wl Hawkins #1         NaN         NaN
# index: 83    LATITUDE  LONGITUDE           WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0    33.385  -101.3963  Phillip Thomas #1      7985.0      8050.0
# 1    33.385  -101.3963  Phillip Thomas #1         NaN         NaN
# index: 83    LATITUDE  LONGITUDE           WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0    33.385  -101.3963  Phillip Thomas #1      7985.0      8050.0
# 1    33.385  -101.3963  Phillip Thomas #1      7985.0         NaN
# index: 84    LATITUDE  LONGITUDE     WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.5493  -101.7004  J.f. Nunn 1         NaN         NaN
# index: 85    LATITUDE  LONGITUDE          WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   32.4103  -101.8641   Harry Lester #1      4030.0      4065.0
# 1   32.4103  -101.8641         #1 Lester      8660.0      8766.0
# 2   32.4103  -101.8641  Anderson Battery         NaN         NaN
# index: 86    LATITUDE  LONGITUDE               WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.9012  -102.5525       #43 J.l. Johnson      5600.0         NaN
# 1   31.9012  -102.5525  J.l. Johnson Unit #43      5636.0      5800.0
# 2   31.9012  -102.5525       #43 J.l. Johnson         NaN         NaN
# index: 86    LATITUDE  LONGITUDE               WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.9012  -102.5525       #43 J.l. Johnson      5600.0         NaN
# 1   31.9012  -102.5525  J.l. Johnson Unit #43      5636.0      5800.0
# 2   31.9012  -102.5525       #43 J.l. Johnson      5618.0         NaN
# index: 87    LATITUDE  LONGITUDE             WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.8676  -102.6589      We Connell #9-d      2330.0      2375.0
# 1   31.8676  -102.6589  W.e. Connell Tr.  D         NaN         NaN
# index: 87    LATITUDE  LONGITUDE             WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.8676  -102.6589      We Connell #9-d      2330.0      2375.0
# 1   31.8676  -102.6589  W.e. Connell Tr.  D      2330.0         NaN
# index: 88    LATITUDE  LONGITUDE         WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.1114  -103.4192  H.t. Collier #1         NaN         NaN
# index: 89    LATITUDE  LONGITUDE            WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.7407   -101.767  Txl Glasscock B #1         NaN         NaN
# 1   31.7407   -101.767  Txl Glasscock #b-1         NaN         NaN
# index: 91    LATITUDE  LONGITUDE          WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0     33.58  -102.0631  Belty Lindsey #1         NaN         NaN
# index: 92    LATITUDE  LONGITUDE        WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.6916  -102.1384      #3 Tippett      5590.0      5653.0
# 1   31.6916  -102.1384  J. Trippett #3         NaN         NaN
# index: 92    LATITUDE  LONGITUDE        WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.6916  -102.1384      #3 Tippett      5590.0      5653.0
# 1   31.6916  -102.1384  J. Trippett #3      5590.0         NaN
# index: 93    LATITUDE  LONGITUDE          WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.6938  -102.1609  June Tippett #10         NaN         NaN
# index: 94    LATITUDE  LONGITUDE            WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.6971  -102.1311  June Tippett #11-c         NaN         NaN
# index: 95    LATITUDE  LONGITUDE          WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.7202  -102.1784  June Tippett #13         NaN         NaN
# index: 96    LATITUDE  LONGITUDE          WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.6857  -102.1318    J. Tippett #16     12752.0     12828.0
# 1   31.6857  -102.1318  June Tippett #16         NaN         NaN
# index: 96    LATITUDE  LONGITUDE          WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.6857  -102.1318    J. Tippett #16     12752.0     12828.0
# 1   31.6857  -102.1318  June Tippett #16     12752.0         NaN
# index: 97    LATITUDE  LONGITUDE            WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.7034  -102.2182       Sanders A-#14     19000.0         NaN
# 1   31.7034  -102.2182  June Sanders #14-t         NaN         NaN
# index: 97    LATITUDE  LONGITUDE            WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.7034  -102.2182       Sanders A-#14     19000.0         NaN
# 1   31.7034  -102.2182  June Sanders #14-t     19000.0         NaN
# index: 98    LATITUDE  LONGITUDE          WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.6943  -102.1313  June Tippett #19         NaN         NaN
# index: 99    LATITUDE  LONGITUDE              WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   33.2923  -102.5635  Ella B. Covington #4         NaN         NaN
# index: 100    LATITUDE  LONGITUDE                      WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0    31.903  -102.5531  J.l. Johnson Jr. Unit Eo #23      4356.0         NaN
# 1    31.903  -102.5531          #23 J.l. Johnson  Eo         NaN         NaN
# index: 100    LATITUDE  LONGITUDE                      WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0    31.903  -102.5531  J.l. Johnson Jr. Unit Eo #23      4356.0         NaN
# 1    31.903  -102.5531          #23 J.l. Johnson  Eo      4356.0         NaN
# index: 101    LATITUDE  LONGITUDE             WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.9359  -102.4383  J.l. Johnson Jr. #1      8859.0      8891.0
# 1   31.9359  -102.4383      J.l. Johnson #1         NaN         NaN
# index: 101    LATITUDE  LONGITUDE             WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.9359  -102.4383  J.l. Johnson Jr. #1      8859.0      8891.0
# 1   31.9359  -102.4383      J.l. Johnson #1      8859.0         NaN
# index: 102    LATITUDE  LONGITUDE         WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   32.4875  -100.1746     J.m. Freeman      5403.0      5546.0
# 1   32.4875  -100.1746  J.m. Freeman #1         NaN         NaN
# index: 102    LATITUDE  LONGITUDE         WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   32.4875  -100.1746     J.m. Freeman      5403.0      5546.0
# 1   32.4875  -100.1746  J.m. Freeman #1      5403.0         NaN
# index: 103    LATITUDE  LONGITUDE                       WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.0903  -102.6948  State Nat. Bank Of E. Paso #1      1566.0      1667.0
# 1   31.0903  -102.6948  State Nat. Bank Of El Paso #1      2555.0      2621.0
# 2   31.0903  -102.6948               1st Nat. Bank #1         NaN         NaN
# index: 104    LATITUDE  LONGITUDE    WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.2669   -101.096  Tract S #2         NaN         NaN
# index: 105    LATITUDE  LONGITUDE          WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.8862   -102.866  Tr 6 #30 Shipley         NaN         NaN
# index: 106    LATITUDE  LONGITUDE               WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.3712  -102.8394  G.p. Cunningham No. 1         NaN         NaN
# index: 107    LATITUDE  LONGITUDE        WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.6985  -103.4982  D D Feldman #1         NaN         NaN
# index: 108    LATITUDE  LONGITUDE         WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.3834  -102.8717  Unit Tract 3 #2         NaN         NaN
# index: 109    LATITUDE  LONGITUDE        WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.6207  -102.1197  V.g. Powell #2         NaN         NaN
# index: 110    LATITUDE  LONGITUDE          WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.3595  -101.8193  U.s. Elliot c 2t         NaN         NaN
# index: 111    LATITUDE  LONGITUDE         WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.8396  -103.1278  F.s. Vaden B #2         NaN         NaN
# index: 112    LATITUDE  LONGITUDE       WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0    31.952  -103.2988  J.b. Tubb a 1      4872.0      4929.0
# 1    31.952  -103.2988  J.b. Tubb a 1      5738.0      5850.0
# 2    31.952  -103.2988  Sealy Smith 4         NaN         NaN
# index: 113    LATITUDE  LONGITUDE                 WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0    31.718  -102.9948       Sealy & Smith Fnd.      4790.0      4850.0
# 1    31.718  -102.9948  Sealy & Smith Fdn No. 1      5045.0      5105.0
# 2    31.718  -102.9948     Sealy And Smith Unit      8030.0      8110.0
# 3    31.718  -102.9948       Sealy & Smith #1-a     11623.0     11695.0
# 4    31.718  -102.9948      Sealy Smith Fdn. #1         NaN         NaN
# index: 114    LATITUDE  LONGITUDE            WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.7263  -101.7842  W.m. Schrock 34 #1      7022.0      7050.0
# 1   31.7263  -101.7842  W.m. Schrock 34 #1      7022.0      7050.0
# 2   31.7263  -101.7842       Schrock 34 #1         NaN         NaN
# 3   31.7263  -101.7842       Schrock 34 #1         NaN         NaN
# index: 114    LATITUDE  LONGITUDE            WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.7263  -101.7842  W.m. Schrock 34 #1      7022.0      7050.0
# 1   31.7263  -101.7842  W.m. Schrock 34 #1      7022.0      7050.0
# 2   31.7263  -101.7842       Schrock 34 #1      7022.0         NaN
# 3   31.7263  -101.7842       Schrock 34 #1      7022.0         NaN
# index: 116    LATITUDE  LONGITUDE       WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.7334  -101.7994     Freeman #3         NaN         NaN
# 1   31.7334  -101.7994      Freeman 3         NaN         NaN
# 2   31.7334  -101.7994  Freeman No. 3         NaN         NaN
# index: 119    LATITUDE  LONGITUDE      WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.7156  -101.7983  Bowles No. 2         NaN         NaN
# index: 120    LATITUDE  LONGITUDE    WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.7352  -101.7914  Freeman #1         NaN         NaN
# index: 121    LATITUDE  LONGITUDE          WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   33.0087  -102.2907  Gustersloh No. 1         NaN         NaN
# index: 122    LATITUDE  LONGITUDE  WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.7192   -101.782  Snyder 5         NaN         NaN
# index: 123    LATITUDE  LONGITUDE      WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.7165  -101.7942  Snyder No. 1         NaN         NaN
# 1   31.7165  -101.7942     Snyder #1         NaN         NaN
# index: 125    LATITUDE  LONGITUDE       WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.1762  -101.4984  Univ. 48 b #1         NaN         NaN
# 1   31.1762  -101.4984  Univ. 48 b #1         NaN         NaN
# 2   31.1762  -101.4984  Univ. 48 b #1         NaN         NaN
# 3   31.1762  -101.4984  Univ. 48 b #1         NaN         NaN
# 4   31.1762  -101.4984  Univ. 48 b #1         NaN         NaN
# 5   31.1762  -101.4984  Univ. 48 b #1         NaN         NaN
# 6   31.1762  -101.4984  Univ. 48 b #1         NaN         NaN
# 7   31.1762  -101.4984  Univ. 48 b #1         NaN         NaN
# index: 133    LATITUDE  LONGITUDE WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   32.5044  -102.2409       #1         NaN         NaN
# index: 134    LATITUDE  LONGITUDE WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   32.2407   -102.914       #1         NaN         NaN
# index: 135    LATITUDE  LONGITUDE WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.4651  -102.4333      NaN         NaN         NaN
# index: 136    LATITUDE  LONGITUDE        WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   32.6091  -102.4388  Terrell Csl #1         NaN         NaN
# index: 137    LATITUDE  LONGITUDE    WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   32.6684  -102.5659  #1 Wescott         NaN         NaN
# index: 138    LATITUDE  LONGITUDE           WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.9166  -102.4872  J.l. Johnson f #1      4082.0      4210.0
# 1   31.9166  -102.4872  J.l. Johnson F #1         NaN         NaN
# index: 138    LATITUDE  LONGITUDE           WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.9166  -102.4872  J.l. Johnson f #1      4082.0      4210.0
# 1   31.9166  -102.4872  J.l. Johnson F #1      4082.0         NaN
# index: 139    LATITUDE  LONGITUDE       WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.9609  -102.7688  Williamson #1      5414.0      5498.0
# 1   31.9609  -102.7688  Williamson #1      7935.0      8035.0
# 2   31.9609  -102.7688  Williamson #1         NaN         NaN
# 3   31.9609  -102.7688  Williamson #1         NaN         NaN
# 4   31.9609  -102.7688  Williamson #1         NaN         NaN
# index: 142    LATITUDE  LONGITUDE          WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.9164  -102.4783  J.l. Johnsone #6         NaN         NaN
# index: 143    LATITUDE  LONGITUDE            WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.8348  -102.4101  F.a. Henderson #11         NaN         NaN
# index: 144    LATITUDE  LONGITUDE           WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.8868  -102.5358  J.l. Johnson #3-b         NaN         NaN
# index: 145    LATITUDE  LONGITUDE      WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0    33.432  -102.7066  C.s. Dean #8         NaN         NaN
# index: 146    LATITUDE  LONGITUDE     WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   33.4588  -102.7107  C.s.dean #7         NaN         NaN
# index: 147    LATITUDE  LONGITUDE     WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   33.4476  -102.7015  C.s.dean #6         NaN         NaN
# index: 148    LATITUDE  LONGITUDE      WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   33.4362  -102.7018  C.s. Dean #2         NaN         NaN
# index: 149    LATITUDE  LONGITUDE   WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   33.0114  -102.9501  Walker #7         NaN         NaN
# index: 150    LATITUDE  LONGITUDE   WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   33.0137  -102.9517  Walker #5         NaN         NaN
# index: 151    LATITUDE  LONGITUDE   WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   33.0167  -102.9524  Walker #8         NaN         NaN
# index: 152    LATITUDE  LONGITUDE         WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.4045  -102.9327  W.d. Johnson #3         NaN         NaN
# index: 153    LATITUDE  LONGITUDE          WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0    31.411  -102.9317  W.d. Johnson #16         NaN         NaN
# 1    31.411  -102.9317  W.d. Johnson #16         NaN         NaN
# 2    31.411  -102.9317  W.d. Johnson #16         NaN         NaN
# 3    31.411  -102.9317  W.d. Johnson #16         NaN         NaN
# 4    31.411  -102.9317  W.d. Johnson #16         NaN         NaN
# 5    31.411  -102.9317  W.d. Johnson #16         NaN         NaN
# 6    31.411  -102.9317  W.d. Johnson #16         NaN         NaN
# index: 160    LATITUDE  LONGITUDE         WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.4034  -102.9311  W.d. Johnson #5      2285.0      2555.0
# 1   31.4034  -102.9311  W.d. Johnson #5         NaN         NaN
# 2   31.4034  -102.9311  W.p. Johnson #5         NaN         NaN
# 3   31.4034  -102.9311  W.d. Johnson #5         NaN         NaN
# 4   31.4034  -102.9311  W.d. Johnson #5         NaN         NaN
# 5   31.4034  -102.9311  W.d. Johnson #5         NaN         NaN
# 6   31.4034  -102.9311  W.d. Johnson #5         NaN         NaN
# 7   31.4034  -102.9311  W.d. Johnson #5         NaN         NaN
# 8   31.4034  -102.9311  W.d. Johnson #5         NaN         NaN
# 9   31.4034  -102.9311  W.d. Johnson #5         NaN         NaN
# index: 160    LATITUDE  LONGITUDE         WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.4034  -102.9311  W.d. Johnson #5      2285.0      2555.0
# 1   31.4034  -102.9311  W.d. Johnson #5      2285.0         NaN
# 2   31.4034  -102.9311  W.p. Johnson #5      2285.0         NaN
# 3   31.4034  -102.9311  W.d. Johnson #5      2285.0         NaN
# 4   31.4034  -102.9311  W.d. Johnson #5      2285.0         NaN
# 5   31.4034  -102.9311  W.d. Johnson #5      2285.0         NaN
# 6   31.4034  -102.9311  W.d. Johnson #5      2285.0         NaN
# 7   31.4034  -102.9311  W.d. Johnson #5      2285.0         NaN
# 8   31.4034  -102.9311  W.d. Johnson #5      2285.0         NaN
# 9   31.4034  -102.9311  W.d. Johnson #5      2285.0         NaN
# index: 169    LATITUDE  LONGITUDE          WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0    31.401  -102.9279  W.d. Johnson #11         NaN         NaN
# index: 170    LATITUDE  LONGITUDE          WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.4011  -102.9249  W.d. Johnson #32         NaN         NaN
# 1   31.4011  -102.9249  W.d. Johnson #32         NaN         NaN
# 2   31.4011  -102.9249  W.d. Johnson #32         NaN         NaN
# 3   31.4011  -102.9249  W.d. Johnson #32         NaN         NaN
# index: 174    LATITUDE  LONGITUDE          WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.4061  -102.9315  W.d. Johnson #29         NaN         NaN
# 1   31.4061  -102.9315  W.d. Johnson #29         NaN         NaN
# 2   31.4061  -102.9315  W.d. Johnson #29         NaN         NaN
# 3   31.4061  -102.9315  W.d. Johnson #29         NaN         NaN
# 4   31.4061  -102.9315  W.d. Johnson #29         NaN         NaN
# 5   31.4061  -102.9315  W.d. Johnson #29         NaN         NaN
# index: 180    LATITUDE  LONGITUDE WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.4772  -102.4467  G G - 1         NaN         NaN
# index: 181    LATITUDE  LONGITUDE            WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.4475  -102.4453            #2 Ellen     10398.0     10460.0
# 1   31.4475  -102.4453        Jt. Op. z #2     10400.0     10460.0
# 2   31.4475  -102.4453  Block 31 Unit z #2         NaN         NaN
# index: 181    LATITUDE  LONGITUDE            WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.4475  -102.4453            #2 Ellen     10398.0     10460.0
# 1   31.4475  -102.4453        Jt. Op. z #2     10400.0     10460.0
# 2   31.4475  -102.4453  Block 31 Unit z #2     10399.0         NaN
# index: 182    LATITUDE  LONGITUDE         WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.1303  -102.1599  J.w. Robbins #1      8534.0      8584.0
# 1   31.1303  -102.1599  J.w. Robbins #1      8684.0      8734.0
# 2   31.1303  -102.1599  J.w. Robbins #1         NaN         NaN
# index: 182    LATITUDE  LONGITUDE         WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.1303  -102.1599  J.w. Robbins #1      8534.0      8584.0
# 1   31.1303  -102.1599  J.w. Robbins #1      8684.0      8734.0
# 2   31.1303  -102.1599  J.w. Robbins #1      8609.0         NaN
# index: 183    LATITUDE  LONGITUDE        WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   32.7181  -101.0543  Sacroc 3 253-4         NaN         NaN
# index: 184    LATITUDE  LONGITUDE       WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   33.4548  -102.7107   C.s. Dean #5      5057.0      5080.0
# 1   33.4548  -102.7107  C. S. Dean #5      5058.0      5080.0
# 2   33.4548  -102.7107   C.s. Dean #5         NaN         NaN
# index: 184    LATITUDE  LONGITUDE       WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   33.4548  -102.7107   C.s. Dean #5      5057.0      5080.0
# 1   33.4548  -102.7107  C. S. Dean #5      5058.0      5080.0
# 2   33.4548  -102.7107   C.s. Dean #5      5057.5         NaN
# index: 185    LATITUDE  LONGITUDE                WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   32.1558  -102.7465  Univ. 11 (sec. 13b) #1      4265.0      4367.0
# 1   32.1558  -102.7465  Univ. 11 (sec. 13) b-1         NaN         NaN
# index: 185    LATITUDE  LONGITUDE                WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   32.1558  -102.7465  Univ. 11 (sec. 13b) #1      4265.0      4367.0
# 1   32.1558  -102.7465  Univ. 11 (sec. 13) b-1      4265.0         NaN
# index: 186    LATITUDE  LONGITUDE               WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   32.1731   -102.752  Univ. 11 (sev 12) 2-a      4260.0      4380.0
# 1   32.1731   -102.752                    NaN         NaN         NaN
# index: 186    LATITUDE  LONGITUDE               WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   32.1731   -102.752  Univ. 11 (sev 12) 2-a      4260.0      4380.0
# 1   32.1731   -102.752                    NaN      4260.0         NaN
# index: 187    LATITUDE  LONGITUDE       WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.4252  -102.5558   Barnsley C-4      8288.0      8313.0
# 1   31.4252  -102.5558  Barnsley C #4      8400.0      8440.0
# 2   31.4252  -102.5558  Barnsley C #4         NaN         NaN
# index: 187    LATITUDE  LONGITUDE       WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.4252  -102.5558   Barnsley C-4      8288.0      8313.0
# 1   31.4252  -102.5558  Barnsley C #4      8400.0      8440.0
# 2   31.4252  -102.5558  Barnsley C #4      8344.0         NaN
# index: 188    LATITUDE  LONGITUDE                 WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.5605   -102.341    Everett & Glass 36 #1      9047.0      9112.0
# 1   31.5605   -102.341  Everett And Glass 36 #1      9050.0      9120.0
# 2   31.5605   -102.341    Everett & Glass 36 #1     11283.0     11345.0
# 3   31.5605   -102.341    Everett & Glass 36 #1     11463.0     11520.0
# 4   31.5605   -102.341      Everett-glass 36 #1     12489.0     12555.0
# 5   31.5605   -102.341    Everett - Glass 36 #1     12555.0     12597.0
# 6   31.5605   -102.341    Everett & Glass 36 #1     12640.0     12690.0
# 7   31.5605   -102.341    Everett & Glass 36 #1         NaN         NaN
# index: 189     LATITUDE  LONGITUDE            WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0    31.4211  -102.5549        Barnsley C-1      2980.0      3024.0
# 1    31.4211  -102.5549        Barnsley C-1      6050.0      6137.0
# 2    31.4211  -102.5549        Barnsley C-1      6120.0      6162.0
# 3    31.4211  -102.5549  Barnsley C - 1 & 2      8128.0      8204.0
# 4    31.4211  -102.5549       Barnsley C #1      8135.0      8153.0
# 5    31.4211  -102.5549       Barnsley C-1t      8138.0      8156.0
# 6    31.4211  -102.5549         Barnsley #1      8218.0      8284.0
# 7    31.4211  -102.5549        Barnsley 1&2      8218.0      8284.0
# 8    31.4211  -102.5549    T.c. Barnsley #1      8354.0      8385.0
# 9    31.4211  -102.5549    M.l. Barnsley #1         NaN         NaN
# 10   31.4211  -102.5549         Barnsley #1         NaN         NaN
# index: 191    LATITUDE  LONGITUDE              WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.3993   -102.599          Barnsley B#1      2600.0      2700.0
# 1   31.3993   -102.599          Barnsley B#1      2701.0      2785.0
# 2   31.3993   -102.599          Barnsley B-1      4225.0      4415.0
# 3   31.3993   -102.599          Barnsley B-1      4275.0      4375.0
# 4   31.3993   -102.599          Barnsley B-1      4275.0      4350.0
# 5   31.3993   -102.599  M.l. Barnsley #1& Up      8335.0      8356.0
# 6   31.3993   -102.599          Barnsley B-1         NaN         NaN
# index: 192    LATITUDE  LONGITUDE       WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.9679  -102.7711  Williamson #3      7945.0      7985.0
# 1   31.9679  -102.7711  Williamson #3      9815.0      9842.0
# 2   31.9679  -102.7711  Williamson #3      9815.0      9842.0
# 3   31.9679  -102.7711  Williamson #3         NaN         NaN
# 4   31.9679  -102.7711  Williamson #3         NaN         NaN
# index: 194    LATITUDE  LONGITUDE          WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0    32.019  -102.5423  Blakeney B No. 3      5105.0      5148.0
# 1    32.019  -102.5423      Blakeney B#3         NaN         NaN
# index: 194    LATITUDE  LONGITUDE          WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0    32.019  -102.5423  Blakeney B No. 3      5105.0      5148.0
# 1    32.019  -102.5423      Blakeney B#3      5105.0         NaN
# index: 195    LATITUDE  LONGITUDE         WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   32.0846  -102.5678        Holt B-12         NaN         NaN
# 1   32.0846  -102.5678  O. B. Holt B#10         NaN         NaN
# index: 197    LATITUDE  LONGITUDE  WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0    31.908  -102.7379  Txl b #5      9790.0      9817.0
# 1    31.908  -102.7379   Txl B-5         NaN         NaN
# 2    31.908  -102.7379   Txl B-5         NaN         NaN
# index: 197    LATITUDE  LONGITUDE  WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0    31.908  -102.7379  Txl b #5      9790.0      9817.0
# 1    31.908  -102.7379   Txl B-5      9790.0         NaN
# 2    31.908  -102.7379   Txl B-5      9790.0         NaN
# index: 199    LATITUDE  LONGITUDE    WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.9899  -102.7738     Txl K#1      7890.0      8352.0
# 1   31.9899  -102.7738     Txl K-1      7890.0      8352.0
# 2   31.9899  -102.7738       Txl k         NaN         NaN
# 3   31.9899  -102.7738  Txl K#1 Ut         NaN         NaN
# index: 199    LATITUDE  LONGITUDE    WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.9899  -102.7738     Txl K#1      7890.0      8352.0
# 1   31.9899  -102.7738     Txl K-1      7890.0      8352.0
# 2   31.9899  -102.7738       Txl k      7890.0         NaN
# 3   31.9899  -102.7738  Txl K#1 Ut      7890.0         NaN
# index: 201    LATITUDE  LONGITUDE   WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   32.9357  -100.2406  Pardue #3      3765.0         NaN
# 1   32.9357  -100.2406  Pardue #3         NaN         NaN
# 2   32.9357  -100.2406  Pardue #3         NaN         NaN
# 3   32.9357  -100.2406  Pardue #2         NaN         NaN
# 4   32.9357  -100.2406  Pardue #2         NaN         NaN
# index: 201    LATITUDE  LONGITUDE   WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   32.9357  -100.2406  Pardue #3      3765.0         NaN
# 1   32.9357  -100.2406  Pardue #3      3765.0         NaN
# 2   32.9357  -100.2406  Pardue #3      3765.0         NaN
# 3   32.9357  -100.2406  Pardue #2      3765.0         NaN
# 4   32.9357  -100.2406  Pardue #2      3765.0         NaN
# index: 203    LATITUDE  LONGITUDE   WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   32.9304  -100.2389  Pardue #1       400.0       494.0
# 1   32.9304  -100.2389  Pardue #1      3784.0      3787.0
# 2   32.9304  -100.2389  Pardue #1      5946.0      5989.0
# 3   32.9304  -100.2389  Pardue #1      5962.0      5989.0
# 4   32.9304  -100.2389   Pardue 1      5962.0      5989.0
# 5   32.9304  -100.2389  Pardue #1         NaN         NaN
# 6   32.9304  -100.2389  Pardue #1         NaN         NaN
# 7   32.9304  -100.2389  Pardue #1         NaN         NaN
# index: 205    LATITUDE  LONGITUDE          WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   32.9392  -100.2306     J.b. Young #8      3746.0      3755.0
# 1   32.9392  -100.2306    J. B. Young #1      3760.0      3765.0
# 2   32.9392  -100.2306     J.b. Young #1      3760.0      3765.0
# 3   32.9392  -100.2306     J.b. Young #1         NaN         NaN
# 4   32.9392  -100.2306     J.b. Young #1         NaN         NaN
# 5   32.9392  -100.2306  J.b. Young Lease         NaN         NaN
# index: 205    LATITUDE  LONGITUDE          WELLNAME   DEPTHUPPER  DEPTHLOWER
# 0   32.9392  -100.2306     J.b. Young #8  3746.000000      3755.0
# 1   32.9392  -100.2306    J. B. Young #1  3760.000000      3765.0
# 2   32.9392  -100.2306     J.b. Young #1  3760.000000      3765.0
# 3   32.9392  -100.2306     J.b. Young #1  3755.333333         NaN
# 4   32.9392  -100.2306     J.b. Young #1  3755.333333         NaN
# 5   32.9392  -100.2306  J.b. Young Lease  3755.333333         NaN
# index: 206    LATITUDE  LONGITUDE       WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   32.9411  -100.2223       Young #5      3748.0      3757.0
# 1   32.9411  -100.2223  J.b. Young #3      3750.0      3752.0
# 2   32.9411  -100.2223     J.b. Young      3750.0      3752.0
# 3   32.9411  -100.2223  J.b. Young #5         NaN         NaN
# 4   32.9411  -100.2223  J.b. Young #5         NaN         NaN
# 5   32.9411  -100.2223  J.b. Young #5         NaN         NaN
# 6   32.9411  -100.2223       Young #5         NaN         NaN
# index: 206    LATITUDE  LONGITUDE       WELLNAME   DEPTHUPPER  DEPTHLOWER
# 0   32.9411  -100.2223       Young #5  3748.000000      3757.0
# 1   32.9411  -100.2223  J.b. Young #3  3750.000000      3752.0
# 2   32.9411  -100.2223     J.b. Young  3750.000000      3752.0
# 3   32.9411  -100.2223  J.b. Young #5  3749.333333         NaN
# 4   32.9411  -100.2223  J.b. Young #5  3749.333333         NaN
# 5   32.9411  -100.2223  J.b. Young #5  3749.333333         NaN
# 6   32.9411  -100.2223       Young #5  3749.333333         NaN
# index: 209    LATITUDE  LONGITUDE    WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.7143  -101.7489  Lane 37 #3      6514.0      6526.0
# 1   31.7143  -101.7489  Lane 37 #3      6514.0      6526.0
# 2   31.7143  -101.7489  Lane 37 #3         NaN         NaN
# index: 209    LATITUDE  LONGITUDE    WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.7143  -101.7489  Lane 37 #3      6514.0      6526.0
# 1   31.7143  -101.7489  Lane 37 #3      6514.0      6526.0
# 2   31.7143  -101.7489  Lane 37 #3      6514.0         NaN
# index: 210    LATITUDE  LONGITUDE WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.2954  -102.8647       #1      6800.0      6860.0
# 1   31.2954  -102.8647       #1         NaN         NaN
# 2   31.2954  -102.8647       #1         NaN         NaN
# 3   31.2954  -102.8647       #1         NaN         NaN
# index: 210    LATITUDE  LONGITUDE WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.2954  -102.8647       #1      6800.0      6860.0
# 1   31.2954  -102.8647       #1      6800.0         NaN
# 2   31.2954  -102.8647       #1      6800.0         NaN
# 3   31.2954  -102.8647       #1      6800.0         NaN
# index: 213    LATITUDE  LONGITUDE            WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.4595  -102.4714        Block 31 S-1      8575.0      8956.0
# 1   31.4595  -102.4714  Block 31 Unit S #1      8575.0      8956.0
# 2   31.4595  -102.4714         Blk 31 S #1         NaN         NaN
# index: 213    LATITUDE  LONGITUDE            WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.4595  -102.4714        Block 31 S-1      8575.0      8956.0
# 1   31.4595  -102.4714  Block 31 Unit S #1      8575.0      8956.0
# 2   31.4595  -102.4714         Blk 31 S #1      8575.0         NaN
# index: 214    LATITUDE  LONGITUDE         WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.5673  -102.5761                4      3493.0         NaN
# 1   31.5673  -102.5761       Connell #4      3588.0      3638.0
# 2   31.5673  -102.5761  W.e. Connell #4      3638.0         NaN
# 3   31.5673  -102.5761  W.e. Connell #4         NaN         NaN
# index: 214    LATITUDE  LONGITUDE         WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.5673  -102.5761                4      3493.0         NaN
# 1   31.5673  -102.5761       Connell #4      3588.0      3638.0
# 2   31.5673  -102.5761  W.e. Connell #4      3638.0         NaN
# 3   31.5673  -102.5761  W.e. Connell #4      3573.0         NaN
# index: 215    LATITUDE  LONGITUDE           WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.5654  -102.5841         Connell #1      2840.0      2845.0
# 1   31.5654  -102.5841  W.e. Connell B #1      3542.0      3573.0
# 2   31.5654  -102.5841         Connell #1         NaN         NaN
# index: 215    LATITUDE  LONGITUDE           WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.5654  -102.5841         Connell #1      2840.0      2845.0
# 1   31.5654  -102.5841  W.e. Connell B #1      3542.0      3573.0
# 2   31.5654  -102.5841         Connell #1      3191.0         NaN
# index: 216    LATITUDE  LONGITUDE            WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.7235  -101.7964       Schrock 34 #7         NaN         NaN
# 1   31.7235  -101.7964       Schrock 34 #7         NaN         NaN
# 2   31.7235  -101.7964  W.m. Schrock 34 #7         NaN         NaN
# 3   31.7235  -101.7964       Schrock 34 #7         NaN         NaN
# index: 220    LATITUDE  LONGITUDE   WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.6651  -102.5558  Utex b #6      3334.0      3650.0
# 1   31.6651  -102.5558  Utex b #6      3500.0      3650.0
# 2   31.6651  -102.5558       B #6         NaN         NaN
# index: 220    LATITUDE  LONGITUDE   WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.6651  -102.5558  Utex b #6      3334.0      3650.0
# 1   31.6651  -102.5558  Utex b #6      3500.0      3650.0
# 2   31.6651  -102.5558       B #6      3417.0         NaN
# index: 221    LATITUDE  LONGITUDE         WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0     31.16  -100.9136  North Estate #1      1605.0      1640.0
# 1     31.16  -100.9136        Nolke B#1      7413.0      7466.0
# 2     31.16  -100.9136  #1 North Estate         NaN         NaN
# 3     31.16  -100.9136  North Estate #1         NaN         NaN
# index: 223    LATITUDE  LONGITUDE          WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.4037  -102.9251  W.d. Johnson #31         NaN         NaN
# 1   31.4037  -102.9251  W.d. Johnson #31         NaN         NaN
# 2   31.4037  -102.9251  W.d. Johnson #31         NaN         NaN
# 3   31.4037  -102.9251  W.d. Johnson #31         NaN         NaN
# index: 227    LATITUDE  LONGITUDE      WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.5597  -102.9969  Wickett a #1      2450.0      2770.0
# 1   31.5597  -102.9969    Wickett #1         NaN         NaN
# index: 227    LATITUDE  LONGITUDE      WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.5597  -102.9969  Wickett a #1      2450.0      2770.0
# 1   31.5597  -102.9969    Wickett #1      2450.0         NaN
# index: 228    LATITUDE  LONGITUDE            WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.1316  -102.2978  Cordova Union B #2      1009.0         NaN
# 1   31.1316  -102.2978  Cordova Union B #2      3385.0      3437.0
# 2   31.1316  -102.2978   Cordova Union B-2      5506.0      5520.0
# 3   31.1316  -102.2978  Cordouz Union b #2         NaN         NaN
# 4   31.1316  -102.2978        Cordova b #2         NaN         NaN
# 5   31.1316  -102.2978  Cordova Union b #2         NaN         NaN
# index: 231    LATITUDE  LONGITUDE             WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   33.0385  -102.8553  Charlie Anderson #1         NaN         NaN
# index: 232    LATITUDE  LONGITUDE          WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.4057  -102.9343   W.d. Johnson #2         NaN         NaN
# 1   31.4057  -102.9343   W.d. Johnson #2         NaN         NaN
# 2   31.4057  -102.9343  W. D. Johnson #2         NaN         NaN
# 3   31.4057  -102.9343   W.d. Johnson #2         NaN         NaN
# 4   31.4057  -102.9343   W.d. Johnson #2         NaN         NaN
# 5   31.4057  -102.9343   W.d. Johnson #2         NaN         NaN
# 6   31.4057  -102.9343  W. D. Johnson #2         NaN         NaN
# 7   31.4057  -102.9343  W. D. Johnson #2         NaN         NaN
# 8   31.4057  -102.9343  W. D. Johnson #2         NaN         NaN
# 9   31.4057  -102.9343  W. D. Johnson #2         NaN         NaN
# index: 242    LATITUDE  LONGITUDE      WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   33.4477  -102.7065  C.s. Dean #9      5066.0      5070.0
# 1   33.4477  -102.7065  C.s. Dean #9         NaN         NaN
# index: 242    LATITUDE  LONGITUDE      WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   33.4477  -102.7065  C.s. Dean #9      5066.0      5070.0
# 1   33.4477  -102.7065  C.s. Dean #9      5066.0         NaN
# index: 243    LATITUDE  LONGITUDE      WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   33.4367  -102.7541  C.s. Dean #1         NaN         NaN
# 1   33.4367  -102.7541  C.s. Dean #1         NaN         NaN
# 2   33.4367  -102.7541  C.s. Dean #4         NaN         NaN
# 3   33.4367  -102.7541  C.s. Dean #7         NaN         NaN
# index: 247    LATITUDE  LONGITUDE                 WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.0554  -102.3959  Alamo National Bank # 1      3044.0      3099.0
# 1   31.0554  -102.3959      Alamo National Bank         NaN         NaN
# index: 247    LATITUDE  LONGITUDE                 WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.0554  -102.3959  Alamo National Bank # 1      3044.0      3099.0
# 1   31.0554  -102.3959      Alamo National Bank      3044.0         NaN
# index: 248    LATITUDE  LONGITUDE           WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.4061  -102.9283   W.d. Johnson #28         NaN         NaN
# 1   31.4061  -102.9283  W. D. Johnson #28         NaN         NaN
# 2   31.4061  -102.9283   W.d. Johnson #28         NaN         NaN
# 3   31.4061  -102.9283  W. D. Johnson #28         NaN         NaN
# 4   31.4061  -102.9283  W. D. Johnson #28         NaN         NaN
# 5   31.4061  -102.9283  W. D. Johnson #28         NaN         NaN
# 6   31.4061  -102.9283  W. D. Johnson #28         NaN         NaN
# 7   31.4061  -102.9283   W.d. Johnson #28         NaN         NaN
# index: 256    LATITUDE  LONGITUDE WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.4502  -102.4638       #2         NaN         NaN
# 1   31.4502  -102.4638       #2         NaN         NaN
# 2   31.4502  -102.4638     Pl#2         NaN         NaN
# index: 259    LATITUDE  LONGITUDE             WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.4728  -102.4496      Block 31  Aa #1      8730.0      8950.0
# 1   31.4728  -102.4496  University  Aa 31#1      8730.0      8950.0
# 2   31.4728  -102.4496                   #1      8730.0      8950.0
# 3   31.4728  -102.4496        Block 31 Aa#1      8730.0      8950.0
# ...
# 2   31.9712  -103.1475  Scarborough C 3         NaN         NaN
# index: 4883    LATITUDE  LONGITUDE         WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.9712  -103.1475  Scarborough C 3      3000.0         NaN
# 1   31.9712  -103.1475  Scarborough C 3      3000.0         NaN
# 2   31.9712  -103.1475  Scarborough C 3      3000.0         NaN
# index: 4885    LATITUDE  LONGITUDE         WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0    31.973  -103.1481  Scarborough C 4         NaN         NaN
# index: 4886    LATITUDE  LONGITUDE         WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.9756  -103.1514  Scarborough C 8         NaN         NaN
# index: 4887    LATITUDE  LONGITUDE     WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.9863  -103.2107  Edwards B 1         NaN         NaN
# index: 4888    LATITUDE  LONGITUDE        WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.8588  -103.1676  Ida Hendrick 2      3000.0         NaN
# 1   31.8588  -103.1676  Ida Hendrick 2         NaN         NaN
# index: 4888    LATITUDE  LONGITUDE        WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.8588  -103.1676  Ida Hendrick 2      3000.0         NaN
# 1   31.8588  -103.1676  Ida Hendrick 2      3000.0         NaN
# index: 4889    LATITUDE  LONGITUDE    WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.8292  -103.1769  Hendrick 1      2769.0      2790.0
# 1   31.8292  -103.1769  Hendrick 1         NaN         NaN
# 2   31.8292  -103.1769  Hendrick 1         NaN         NaN
# index: 4889    LATITUDE  LONGITUDE    WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.8292  -103.1769  Hendrick 1      2769.0      2790.0
# 1   31.8292  -103.1769  Hendrick 1      2769.0         NaN
# 2   31.8292  -103.1769  Hendrick 1      2769.0         NaN
# index: 4891    LATITUDE  LONGITUDE        WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.8217   -103.092  Brown-altman 3         NaN         NaN
# index: 4892    LATITUDE  LONGITUDE       WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.8646  -103.1631  Daugherty B 1      2745.0      2882.0
# 1   31.8646  -103.1631  Daugherty B 1      2745.0      2882.0
# 2   31.8646  -103.1631  Daugherty B 1      2745.0      2882.0
# 3   31.8646  -103.1631  Daugherty B 1         NaN         NaN
# 4   31.8646  -103.1631  Daugherty B 1         NaN         NaN
# 5   31.8646  -103.1631  Daugherty B 1         NaN         NaN
# index: 4892    LATITUDE  LONGITUDE       WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.8646  -103.1631  Daugherty B 1      2745.0      2882.0
# 1   31.8646  -103.1631  Daugherty B 1      2745.0      2882.0
# 2   31.8646  -103.1631  Daugherty B 1      2745.0      2882.0
# 3   31.8646  -103.1631  Daugherty B 1      2745.0         NaN
# 4   31.8646  -103.1631  Daugherty B 1      2745.0         NaN
# 5   31.8646  -103.1631  Daugherty B 1      2745.0         NaN
# index: 4895    LATITUDE  LONGITUDE            WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.6578  -103.0102  Gw Obrien Etal 647         NaN         NaN
# index: 4896    LATITUDE  LONGITUDE      WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.8078  -103.1508  Hendrick #10      2325.0      2689.0
# 1   31.8078  -103.1508   Hendrick 10         NaN         NaN
# index: 4896    LATITUDE  LONGITUDE      WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.8078  -103.1508  Hendrick #10      2325.0      2689.0
# 1   31.8078  -103.1508   Hendrick 10      2325.0         NaN
# index: 4897    LATITUDE  LONGITUDE WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.9285  -103.1679    Lum 5         NaN         NaN
# index: 4898    LATITUDE  LONGITUDE        WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0     31.75  -103.1317  Ida Hendrick 1         NaN         NaN
# index: 4899    LATITUDE  LONGITUDE   WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.8972  -102.8413  Waddell 1         NaN         NaN
# index: 4900    LATITUDE  LONGITUDE           WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.8009  -103.1688  Ida Hendrick #d-1         NaN         NaN
# 1   31.8009  -103.1688   Ida Hendrick D 1         NaN         NaN
# index: 4901    LATITUDE  LONGITUDE      WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.7996  -103.1525  Hendrick A 7         NaN         NaN
# index: 4902    LATITUDE  LONGITUDE               WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.9545  -103.0834  Continental-jenkins 9         NaN         NaN
# index: 4903    LATITUDE  LONGITUDE      WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.9423  -103.0481  Jb Walton 16      9907.0      9910.0
# 1   31.9423  -103.0481  Jb Walton 16      9907.0      9917.0
# 2   31.9423  -103.0481  Jb Walton 16         NaN         NaN
# index: 4903    LATITUDE  LONGITUDE      WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.9423  -103.0481  Jb Walton 16      9907.0      9910.0
# 1   31.9423  -103.0481  Jb Walton 16      9907.0      9917.0
# 2   31.9423  -103.0481  Jb Walton 16      9907.0         NaN
# index: 4904    LATITUDE  LONGITUDE      WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.9366  -103.0549  Jb Walton 10         NaN         NaN
# index: 4905    LATITUDE  LONGITUDE         WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.9656  -103.1454  Scarborough A 6      2800.0      3000.0
# 1   31.9656  -103.1454  Scarborough A 6      2800.0      3000.0
# 2   31.9656  -103.1454  Scarborough A 6      3000.0         NaN
# 3   31.9656  -103.1454  Scarborough A 6      3000.0         NaN
# 4   31.9656  -103.1454  Scarborough A 6         NaN         NaN
# 5   31.9656  -103.1454  Scarborough A 6         NaN         NaN
# index: 4905    LATITUDE  LONGITUDE         WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.9656  -103.1454  Scarborough A 6      2800.0      3000.0
# 1   31.9656  -103.1454  Scarborough A 6      2800.0      3000.0
# 2   31.9656  -103.1454  Scarborough A 6      3000.0         NaN
# 3   31.9656  -103.1454  Scarborough A 6      3000.0         NaN
# 4   31.9656  -103.1454  Scarborough A 6      2900.0         NaN
# 5   31.9656  -103.1454  Scarborough A 6      2900.0         NaN
# index: 4907    LATITUDE  LONGITUDE             WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.6637  -102.9699  Sealy-smith Fdn A 1      5096.0      5124.0
# 1   31.6637  -102.9699  Sealy-smith Fdn A 1      5146.0      5166.0
# 2   31.6637  -102.9699  Sealy-smith Fdn A 1      5146.0      5166.0
# 3   31.6637  -102.9699  Sealy-smith Fdn A 1         NaN         NaN
# index: 4907    LATITUDE  LONGITUDE             WELLNAME   DEPTHUPPER  DEPTHLOWER
# 0   31.6637  -102.9699  Sealy-smith Fdn A 1  5096.000000      5124.0
# 1   31.6637  -102.9699  Sealy-smith Fdn A 1  5146.000000      5166.0
# 2   31.6637  -102.9699  Sealy-smith Fdn A 1  5146.000000      5166.0
# 3   31.6637  -102.9699  Sealy-smith Fdn A 1  5129.333333         NaN
# index: 4908    LATITUDE  LONGITUDE           WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0    31.856  -103.1598  Hendrick T-88 Q 2         NaN         NaN
# index: 4909    LATITUDE  LONGITUDE        WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.8921  -103.0632  We Baird 19 23         NaN         NaN
# index: 4910    LATITUDE  LONGITUDE              WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.8572  -102.8066  R.a. Wheeler e No. 1         NaN         NaN
# 1   31.8572  -102.8066          Ra Wheeler 1         NaN         NaN
# 2   31.8572  -102.8066          Ra Wheeler 1         NaN         NaN
# index: 4912    LATITUDE  LONGITUDE          WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.7668  -103.1255  Ida Hendrick B 1         NaN         NaN
# index: 4913    LATITUDE  LONGITUDE          WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.8215  -103.1425  Ida Hendrick B 3         NaN         NaN
# index: 4914    LATITUDE  LONGITUDE          WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.8181  -103.1413  Ida Hendrick B 2         NaN         NaN
# index: 4915    LATITUDE  LONGITUDE       WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.7688  -103.0463  Sm Halley B 1         NaN         NaN
# 1   31.7688  -103.0463  Sm Halley B 1         NaN         NaN
# index: 4917    LATITUDE  LONGITUDE  WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0    31.719  -103.0589  Halley 2         NaN         NaN
# index: 4918    LATITUDE  LONGITUDE            WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.7737  -103.0574       Sm Halley B 6      3100.0         NaN
# 1   31.7737  -103.0574  S.m. Halley b #6-t         NaN         NaN
# 2   31.7737  -103.0574       Sm Halley B 6         NaN         NaN
# 3   31.7737  -103.0574       Sm Halley B 6         NaN         NaN
# index: 4918    LATITUDE  LONGITUDE            WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.7737  -103.0574       Sm Halley B 6      3100.0         NaN
# 1   31.7737  -103.0574  S.m. Halley b #6-t      3100.0         NaN
# 2   31.7737  -103.0574       Sm Halley B 6      3100.0         NaN
# 3   31.7737  -103.0574       Sm Halley B 6      3100.0         NaN
# index: 4920    LATITUDE  LONGITUDE                WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.7775  -103.0594  S.m. Halley b Well #11      4717.0      4840.0
# 1   31.7775  -103.0594   S M Halley B Well #11      4717.0      4840.0
# 2   31.7775  -103.0594        S.m. Halley E-11      4803.0      4840.0
# 3   31.7775  -103.0594          Sm Halley B 11      4803.0      4840.0
# 4   31.7775  -103.0594          Sm Halley B 11         NaN         NaN
# index: 4920    LATITUDE  LONGITUDE                WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.7775  -103.0594  S.m. Halley b Well #11      4717.0      4840.0
# 1   31.7775  -103.0594   S M Halley B Well #11      4717.0      4840.0
# 2   31.7775  -103.0594        S.m. Halley E-11      4803.0      4840.0
# 3   31.7775  -103.0594          Sm Halley B 11      4803.0      4840.0
# 4   31.7775  -103.0594          Sm Halley B 11      4760.0         NaN
# index: 4921    LATITUDE  LONGITUDE        WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.7742  -103.0576     Halley B-15      3175.0      3274.0
# 1   31.7742  -103.0576  Sm Halley B 15      3175.0      3274.0
# 2   31.7742  -103.0576  Sm Halley B 15         NaN         NaN
# 3   31.7742  -103.0576  Sm Halley B 15         NaN         NaN
# index: 4921    LATITUDE  LONGITUDE        WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.7742  -103.0576     Halley B-15      3175.0      3274.0
# 1   31.7742  -103.0576  Sm Halley B 15      3175.0      3274.0
# 2   31.7742  -103.0576  Sm Halley B 15      3175.0         NaN
# 3   31.7742  -103.0576  Sm Halley B 15      3175.0         NaN
# index: 4923    LATITUDE  LONGITUDE                 WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.7769  -103.0581  S.h. Halley b No. 22 Lt         NaN         NaN
# 1   31.7769  -103.0581           Sm Halley B 22         NaN         NaN
# index: 4924    LATITUDE  LONGITUDE                      WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.7713  -103.0565            S M Halley B No 25      8925.0     11284.0
# 1   31.7713  -103.0565           S.m. Halley b #25lt     11310.0     11340.0
# 2   31.7713  -103.0565                Sm Halley B 25     11310.0     11340.0
# 3   31.7713  -103.0565  S M Halley B 25 Ut And 25 Lt         NaN         NaN
# 4   31.7713  -103.0565                Sm Halley B 25         NaN         NaN
# index: 4925    LATITUDE  LONGITUDE              WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.9765  -103.0942  Keystone Cattle Co 9     10336.0     10396.0
# 1   31.9765  -103.0942  Keystone Cattle Co 9         NaN         NaN
# index: 4925    LATITUDE  LONGITUDE              WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.9765  -103.0942  Keystone Cattle Co 9     10336.0     10396.0
# 1   31.9765  -103.0942  Keystone Cattle Co 9     10336.0         NaN
# index: 4926    LATITUDE  LONGITUDE       WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.9108  -103.0814  W.b.walton #7         NaN         NaN
# 1   31.9108  -103.0814    Jb Walton 7         NaN         NaN
# 2   31.9108  -103.0814    Jb Walton 7         NaN         NaN
# index: 4928    LATITUDE  LONGITUDE      WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.8801  -102.8183  Ra Wheeler 1         NaN         NaN
# index: 4929    LATITUDE  LONGITUDE      WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.8772  -102.8029  Ra Wheeler 2      9290.0      9300.0
# 1   31.8772  -102.8029  Ra Wheeler 2      9290.0      9300.0
# 2   31.8772  -102.8029  Ra Wheeler 2     10642.0     10652.0
# 3   31.8772  -102.8029  Ra Wheeler 2         NaN         NaN
# index: 4930    LATITUDE  LONGITUDE      WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.8799  -102.8154  Ra Wheeler 4      9147.0      9155.0
# 1   31.8799  -102.8154  Ra Wheeler 4         NaN         NaN
# 2   31.8799  -102.8154  Ra Wheeler 4         NaN         NaN
# index: 4930    LATITUDE  LONGITUDE      WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.8799  -102.8154  Ra Wheeler 4      9147.0      9155.0
# 1   31.8799  -102.8154  Ra Wheeler 4      9147.0         NaN
# 2   31.8799  -102.8154  Ra Wheeler 4      9147.0         NaN
# index: 4932    LATITUDE  LONGITUDE                WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.9101  -103.1559  Lum Daugherty A/c 3 34         NaN         NaN
# index: 4933    LATITUDE  LONGITUDE             WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.7096  -102.9696  Sealy-smith Fdn B 1      5225.0      5357.0
# 1   31.7096  -102.9696  Sealy-smith Fdn B 1         NaN         NaN
# index: 4933    LATITUDE  LONGITUDE             WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.7096  -102.9696  Sealy-smith Fdn B 1      5225.0      5357.0
# 1   31.7096  -102.9696  Sealy-smith Fdn B 1      5225.0         NaN
# index: 4934    LATITUDE  LONGITUDE         WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0    31.749  -103.0869  Tobe Morton A 1         NaN         NaN
# index: 4935    LATITUDE  LONGITUDE          WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.7497  -103.1052  Hendrick Est A 1         NaN         NaN
# index: 4936    LATITUDE  LONGITUDE         WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0    31.808  -103.1416  Tg Hendrick F 2         NaN         NaN
# index: 4937    LATITUDE  LONGITUDE       WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0    31.954  -103.1897  Daugherty 1-x      3000.0         NaN
# 1    31.954  -103.1897  Daugherty 1-x         NaN         NaN
# 2    31.954  -103.1897  Daugherty 1-x         NaN         NaN
# index: 4937    LATITUDE  LONGITUDE       WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0    31.954  -103.1897  Daugherty 1-x      3000.0         NaN
# 1    31.954  -103.1897  Daugherty 1-x      3000.0         NaN
# 2    31.954  -103.1897  Daugherty 1-x      3000.0         NaN
# index: 4939    LATITUDE  LONGITUDE     WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.9529  -103.1938  Daugherty 2      3000.0         NaN
# 1   31.9529  -103.1938  Daugherty 2      3000.0         NaN
# 2   31.9529  -103.1938  Daugherty 2         NaN         NaN
# index: 4939    LATITUDE  LONGITUDE     WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.9529  -103.1938  Daugherty 2      3000.0         NaN
# 1   31.9529  -103.1938  Daugherty 2      3000.0         NaN
# 2   31.9529  -103.1938  Daugherty 2      3000.0         NaN
# index: 4940    LATITUDE  LONGITUDE      WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.8207  -103.1386  Hendrick G 1         NaN         NaN
# index: 4941    LATITUDE  LONGITUDE            WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.8255  -103.1485  Shell-hendrick E 1         NaN         NaN
# 1   31.8255  -103.1485  Shell-hendrick E 1         NaN         NaN
# index: 4943    LATITUDE  LONGITUDE        WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.8804  -103.0974  Mj Bashara A 1         NaN         NaN
# index: 4944    LATITUDE  LONGITUDE  WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.6609  -103.2026  Univ H 1     20100.0     20300.0
# 1   31.6609  -103.2026  Univ H 1     20200.0     20600.0
# 2   31.6609  -103.2026  Univ H 1     20295.0     20498.0
# 3   31.6609  -103.2026  Univ H 1     20600.0     28200.0
# 4   31.6609  -103.2026  Univ H 1         NaN         NaN
# index: 4944    LATITUDE  LONGITUDE  WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.6609  -103.2026  Univ H 1    20100.00     20300.0
# 1   31.6609  -103.2026  Univ H 1    20200.00     20600.0
# 2   31.6609  -103.2026  Univ H 1    20295.00     20498.0
# 3   31.6609  -103.2026  Univ H 1    20600.00     28200.0
# 4   31.6609  -103.2026  Univ H 1    20298.75         NaN
# index: 4945    LATITUDE  LONGITUDE       WELLNAME  DEPTHUPPER  DEPTHLOWER
# 0   31.6578  -102.8967  Sealy-smith 1      5680.0      5750.0
# 1   31.6578  -102.8967  Sealy-smith 1     10000.0         NaN
# 2   31.6578  -102.8967  Sealy-smith 1     10000.0         NaN
# 3   31.6578  -102.8967  Sealy-smith 1     10390.0     10416.0
# 4   31.6578  -102.8967  Sealy-smith 1     10390.0         NaN
# 5   31.6578  -102.8967  Sealy-smith 1         NaN         NaN

# %% [markdown]
# The list <i>filled_depths </i>now contains dataframes of the same wellname, filled with depth values interpolated from previous entries. This would need to be converted into a dataframe.

# %%
df_clean = pd.concat(filled_depths).reset_index(drop=True)

# %%
len(df_drop)
# Out:
# 16631

# %%
len(df_clean)
# Out:
# 14628

# %%
df_drop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16631 entries, 0 to 19386
# Data columns (total 26 columns):
# LATITUDE        16631 non-null float64
# LONGITUDE       16631 non-null float64
# API             8172 non-null float64
# BASIN           16631 non-null object
# COUNTY          16622 non-null object
# WELLNAME        16399 non-null object
# WELLTYPE        16631 non-null object
# DATECOMP        1648 non-null datetime64[ns]
# DATESAMPLE      14255 non-null datetime64[ns]
# FORMATION       16631 non-null object
# PERIOD          16631 non-null object
# DEPTHUPPER      11685 non-null float64
# DEPTHLOWER      9702 non-null float64
# DEPTHWELL       8843 non-null float64
# SPGRAV          14364 non-null object
# PH              14227 non-null object
# TDSUSGS         16619 non-null float64
# HCO3            15967 non-null object
# Ca              16613 non-null object
# Cl              16618 non-null object
# KNa             1850 non-null object
# Mg              16605 non-null object
# Na              14777 non-null object
# SO4             16143 non-null object
# H2S             5419 non-null object
# cull_chargeb    2089 non-null object
# dtypes: datetime64[ns](2), float64(7), object(17)
# memory usage: 4.1+ MB

# %%
permian = df_drop[df_drop.BASIN == 'Permian']
amarillo = df_drop[df_drop.BASIN == 'Amarillo Arch']
anadarko = df_drop[df_drop.BASIN == 'Anadarko']
eastTexas = df_drop[df_drop.BASIN == 'East Texas']
gulf_coast = df_drop[df_drop.BASIN == 'Gulf Coast']
basins = [permian, amarillo,anadarko,eastTexas,gulf_coast]
basin_names = ['Permian','Amarillo','Anadarko','East Texas','Gulf Coast']

# %%
df_drop.groupby('BASIN')['TDSUSGS'].count()
# Out:
# BASIN
# Amarillo Arch           181
# Anadarko                349
# Bend Arch                82
# East Texas             1710
# Fort Worth               84
# Gulf Coast             6762
# Kerr                      4
# Llano Uplift             40
# Ouachita Thrust          15
# Palo Duro               113
# Permian                7135
# Permian - Bend Arch       1
# Southern Oklahoma       142
# Strawn                    1
# Name: TDSUSGS, dtype: int64

# %%
#Distribution of TDS in different basins throughout Texas
fig, axs = plt.subplots(2,3, figsize=(15, 8), facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace = .5, wspace=1)

axs = axs.ravel()

for i in range(5):

    axs[i].hist(basins[i].TDSUSGS, bins=int(np.sqrt(len(basins[i]))),alpha=0.4)
    axs[i].set_title(basin_names[i])

# %%
df_clean.groupby('BASIN')['DEPTHUPPER','TDSUSGS'].count()
# Out:
#                      DEPTHUPPER  TDSUSGS
# BASIN
# Amarillo Arch               931      936
# Anadarko                     65       76
# Bend Arch                     8       15
# East Texas                 4084     4150
# Fort Worth                    6       13
# Gulf Coast                 4807     5253
# Llano Uplift                  6       15
# Ouachita Thrust               5        6
# Palo Duro                    38       39
# Permian                    2907     4122
# Permian - Bend Arch           1        1
# Southern Oklahoma             2        2

# %%
df_drop.groupby('BASIN')['DEPTHUPPER','TDSUSGS'].count()
# Out:
#                      DEPTHUPPER  TDSUSGS
# BASIN
# Amarillo Arch                68      181
# Anadarko                    280      349
# Bend Arch                    71       82
# East Texas                  706     1710
# Fort Worth                   73       84
# Gulf Coast                 5237     6762
# Kerr                          4        4
# Llano Uplift                 29       40
# Ouachita Thrust              13       15
# Palo Duro                   102      113
# Permian                    4976     7135
# Permian - Bend Arch           1        1
# Southern Oklahoma           124      142
# Strawn                        1        1

# %% [markdown]
# Regarding both tables for depths, I will use df_clean for Gulf coast, Permian, East Texas and Amarillo Arch, and will use df_drop for Anadarko

# %%
permian_depth = df_clean[df_clean.BASIN == 'Permian']
amarillo_depth = df_clean[df_clean.BASIN == 'Amarillo Arch']
anadarko_depth = df_drop[df_drop.BASIN == 'Anadarko']
eastTexas_depth = df_clean[df_clean.BASIN == 'East Texas']
gulf_coast_depth = df_clean[df_clean.BASIN == 'Gulf Coast']
basins_depth = [permian_depth, amarillo_depth,anadarko_depth,eastTexas_depth,gulf_coast_depth]

# %%
#Distribution of depths in different basins throughout Texas
fig, axs = plt.subplots(2,3, figsize=(15, 8), facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace = .5, wspace=1)

axs = axs.ravel()

for i in range(5):

    axs[i].hist(basins_depth[i].DEPTHUPPER, bins=int(np.sqrt(len(basins_depth[i]))),alpha=0.4,color='g')
    axs[i].set_title(basin_names[i])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
plt.figure(figsize=(15, 8), facecolor='w', edgecolor='k')
_ = permian.groupby(permian["DATESAMPLE"].dt.year)['TDSUSGS'].count().plot(kind='bar')
#_ = permian.groupby(permian["DATESAMPLE"].dt.year)['TDSUSGS'].mean().plot(color='r',alpha=0.5)

# %%
#EDA
# geo comparisons of well depths upper, lower and point depths (mean, std, count)
depth_geo = df_clean.groupby(['LATITUDE','LONGITUDE'])['DEPTHUPPER','DEPTHLOWER','DEPTHWELL'].agg(['mean','std','count']).reset_index()
depth_geo.columns = depth_geo.columns.droplevel()
depth_geo.columns = ['LATITUDE','LONGITUDE','DUmean','DUstd','DUcount','DLmean','DLstd','DLcount','Dmean','Dstd','Dcount']
depth_geo
# Out:
#       LATITUDE  LONGITUDE        DUmean       DUstd  DUcount        DLmean  \
# 0     26.10700  -98.18600   6979.600000  372.217782       27   6958.521739
# 1     26.11160  -98.01510           NaN         NaN        0           NaN
# 2     26.12210  -98.00940           NaN         NaN        0           NaN
# 3     26.37510  -98.60280           NaN         NaN        0           NaN
# 4     26.39080  -98.62630   3778.000000    0.000000        2   3782.000000
# 5     26.41800  -97.57540           NaN         NaN        0           NaN
# 6     26.41920  -97.57420           NaN         NaN        0           NaN
# 7     26.41980  -97.57240           NaN         NaN        0           NaN
# 8     26.42080  -97.57720           NaN         NaN        0           NaN
# 9     26.42100  -97.57050           NaN         NaN        0           NaN
# 10    26.42270  -97.57590           NaN         NaN        0           NaN
# 11    26.42350  -97.57380           NaN         NaN        0           NaN
# 12    26.42540  -97.57650           NaN         NaN        0           NaN
# 13    26.43500  -97.57000           NaN         NaN        0           NaN
# 14    26.45760  -98.62320           NaN         NaN        0           NaN
# 15    26.47770  -98.40890  11673.000000    0.000000        4  11693.000000
# 16    26.48870  -98.50490           NaN         NaN        0           NaN
# 17    26.50970  -98.50110   3762.666667  189.033213        4           NaN
# 18    26.53080  -98.79380           NaN         NaN        0           NaN
# 19    26.53710  -98.79450   3786.000000    0.000000        2   3794.000000
# 20    26.54070  -98.79390   4390.000000    0.000000        3   4401.000000
# 21    26.57160  -98.50490           NaN         NaN        0           NaN
# 22    26.58490  -98.42960   5959.000000    0.000000        2   5972.000000
# 23    26.59170  -98.38850  11821.250000  286.656916        5  11860.000000
# 24    26.59490  -98.29790           NaN         NaN        0           NaN
# 25    26.59620  -98.49690           NaN         NaN        0           NaN
# 26    26.60550  -98.29570           NaN         NaN        0           NaN
# 27    26.61150  -98.30590           NaN         NaN        0           NaN
# 28    26.61240  -98.31090           NaN         NaN        0           NaN
# 29    26.63870  -98.33860           NaN         NaN        0           NaN
# ...        ...        ...           ...         ...      ...           ...
# 1458  33.89891  -97.70987           NaN         NaN        0           NaN
# 1459  33.89970 -100.76670   4114.333333   47.478316        8   4152.500000
# 1460  33.92000 -100.73200   4020.200000  246.809238        7   4037.600000
# 1461  34.28118  -99.74548   8294.000000    0.000000        3   8346.000000
# 1462  35.35800 -101.98000   3251.916667  262.538829       15   3628.250000
# 1463  35.52900 -100.58100           NaN         NaN        0           NaN
# 1464  35.69578 -100.11523   8313.000000    0.000000        2   8417.000000
# 1465  35.69617 -100.07190   6032.000000    0.000000        2   6044.000000
# 1466  35.70300 -100.80900   4113.500000   29.500000        3   4129.500000
# 1467  35.71050 -100.07219   8102.000000    0.000000        2   8170.000000
# 1468  35.71242 -100.10124   5873.500000   26.500000        3   5889.500000
# 1469  35.73200 -101.60500   3134.687500   60.983358      896   3236.000000
# 1470  35.73500 -101.66800   3135.000000    0.000000       20   3303.000000
# 1471  35.89330 -100.37518           NaN         NaN        0           NaN
# 1472  35.90900 -101.41700   1969.000000    0.000000        2   2018.000000
# 1473  36.00213 -100.61746           NaN         NaN        0           NaN
# 1474  36.01800 -100.57000  11133.000000    0.000000        6  11145.000000
# 1475  36.06056 -100.12136           NaN         NaN        0           NaN
# 1476  36.16800 -101.03300   7400.000000    0.000000        3   7967.000000
# 1477  36.17700 -100.97000   8026.000000    0.000000       24   8044.000000
# 1478  36.19679 -101.42040           NaN         NaN        0           NaN
# 1479  36.24300 -100.72600           NaN         NaN        0           NaN
# 1480  36.24400 -100.94700   7986.000000   15.118579        8   8007.000000
# 1481  36.26200 -101.82700   3010.200000  124.660178        6   3230.250000
# 1482  36.31800 -100.11100           NaN         NaN        0           NaN
# 1483  36.34700 -100.18400           NaN         NaN        0           NaN
# 1484  36.35863 -100.09761           NaN         NaN        0           NaN
# 1485  36.36800 -100.84200   7983.000000    0.000000        2   7993.000000
# 1486  36.37465 -101.17023           NaN         NaN        0           NaN
# 1487  36.38100 -101.34900           NaN         NaN        0           NaN
#
#            DLstd  DLcount         Dmean        Dstd  Dcount
# 0     374.984469       23   7416.277778  370.774199      18
# 1            NaN        0   9200.000000         NaN       1
# 2            NaN        0   9003.000000         NaN       1
# 3            NaN        0   4617.000000         NaN       1
# 4            NaN        1   4172.000000    0.000000       2
# 5            NaN        0   7976.000000         NaN       1
# 6            NaN        0   7984.000000         NaN       1
# 7            NaN        0   8000.000000         NaN       1
# 8            NaN        0   7970.000000         NaN       1
# 9            NaN        0   7978.000000         NaN       1
# 10           NaN        0   7980.000000         NaN       1
# 11           NaN        0   7970.000000         NaN       1
# 12           NaN        0   7975.000000         NaN       1
# 13           NaN        0           NaN         NaN       0
# 14           NaN        0   4400.000000         NaN       1
# 15           NaN        1  13923.000000    0.000000       4
# 16           NaN        0   5703.000000         NaN       1
# 17           NaN        0   5612.000000    0.000000       4
# 18           NaN        0   4675.000000         NaN       1
# 19           NaN        1   4503.000000    0.000000       2
# 20           NaN        1   4500.000000    0.000000       3
# 21           NaN        0  10355.000000         NaN       1
# 22           NaN        1   6605.000000    0.000000       2
# 23    328.277322        4  12795.000000    0.000000       5
# 24           NaN        0  13963.000000    0.000000       2
# 25           NaN        0  10392.000000         NaN       1
# 26           NaN        0  12500.000000    0.000000       3
# 27           NaN        0  13920.000000         NaN       1
# 28           NaN        0  13000.000000         NaN       1
# 29           NaN        0  11069.000000         NaN       1
# ...          ...      ...           ...         ...     ...
# 1458         NaN        0   1675.000000         NaN       1
# 1459   12.597619        6   4237.000000    0.000000       8
# 1460  297.647946        5           NaN         NaN       0
# 1461    0.000000        2   8857.000000    0.000000       3
# 1462  137.588154        8   3549.500000  283.385976      10
# 1463         NaN        0           NaN         NaN       0
# 1464         NaN        1  15808.000000    0.000000       2
# 1465         NaN        1  20450.000000    0.000000       2
# 1466   36.062446        2   4100.000000         NaN       1
# 1467         NaN        1   8502.000000   70.710678       2
# 1468   20.506097        2  16600.000000    0.000000       3
# 1469  121.781409      105   3343.746269   84.401700     469
# 1470    0.000000        2   3113.000000   33.067424      12
# 1471         NaN        0   7445.500000   41.719300       2
# 1472         NaN        1           NaN         NaN       0
# 1473         NaN        0  11233.000000         NaN       1
# 1474    0.000000        2  11230.000000    0.000000       2
# 1475         NaN        0   7685.000000         NaN       1
# 1476         NaN        1   8478.500000   23.334524       2
# 1477    0.000000        4   8300.200000   63.476146      20
# 1478         NaN        0   7215.000000         NaN       1
# 1479         NaN        0   9710.000000         NaN       1
# 1480   19.629909        4           NaN         NaN       0
# 1481  122.532649        4   3240.750000  142.647292       4
# 1482         NaN        0           NaN         NaN       0
# 1483         NaN        0           NaN         NaN       0
# 1484         NaN        0   9910.000000         NaN       1
# 1485         NaN        1           NaN         NaN       0
# 1486         NaN        0   5353.000000         NaN       1
# 1487         NaN        0           NaN         NaN       0
#
# [1488 rows x 11 columns]

# %%
extra_wells = []
for ind in df_drop.index:
    if not df_clean['index'].isin([ind]).any():
        extra_wells.append(df_drop.loc[ind,:])
    
    if ind == 50:
        break

# %% [markdown]
# Using this initial data, I was able to plot the latitude, longitude and depths on a 3D map, as follows:

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
sns.scatterplot(x=APIm.LONGITUDE, y=APIm.LATITUDE, hue=APIm.DEPTHUPPER, cmap='red',s=60)

# %%
plt.figure()
sns.scatterplot(x=APIm.LONGITUDE, y=APIm.LATITUDE, hue=APIm.TDSUSGS, color='blue')

# %%
formations = []
for formation in df_drop['FORMATION']:
    if not formation in formations:
        formations.append(formation)
        
print(formations[:20])
# Out:
# ['Fusselman', 'Cline Shale', 'Wolfwood (Wolfcamp/Woodford)', 'Spraberry', 'Dean', 'Wolfcamp Shale', 'Spraberry, Strawn, Fusselman', 'Otoka/Barnett Shale', 'Strawn, Atoka, Mississipain Lime, Spraberry', 'Strawn, Atoka, Spraberry', 'Multiple Reservoirs', 'Spraberry, Wolfcamp, and Pennsylvanian', 'Edwards', 'Frio', 'Hosston / Cotton Valley', 'Miocene', 'Vicksburg', 'Wilcox', 'Austin Chalk', 'Frio A']
